# %%
#setup game
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
done = True
for step in range(100000): 
    if done: 
        env.reset()
    state, reward, done, info = env.step(env.action_space.sample())
    env.render()
env.close()

# %%
#preprocess environment
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from matplotlib import pyplot as plt


env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)
env = GrayScaleObservation(env, keep_dim=True) #less colors = less processing
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last') #kind of like the computer keeping track, here remembers 4 frames in last order

# %%
#training the reinforcement learning model
import os
from stable_baselines3 import PPO #algorithm
from stable_baselines3.common.callbacks import BaseCallback #for saving state of trained AI

# %%
#saves model every X steps so it doesnt have to be retrained
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
callback = TrainAndLoggingCallback(check_freq=100000, save_path=CHECKPOINT_DIR)

# %%
#AI model
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, n_steps=512)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
#start of training ai model
model.learn(total_timesteps=1000000, callback=callback)
# Out:
# Logging to ./logs/PPO_1
# ----------------------------
# | time/              |     |
# |    fps             | 74  |
# |    iterations      | 1   |
# |    time_elapsed    | 6   |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 15            |
# |    iterations           | 2             |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 6.6111097e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00246      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 264           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -5.04e-05     |
# |    value_loss           | 673           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 3             |
# |    time_elapsed         | 123           |
# |    total_timesteps      | 1536          |
# | train/                  |               |
# |    approx_kl            | 0.00015107321 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00509       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 44.7          |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.00122      |
# |    value_loss           | 90.6          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 4           |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 3.50771e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.95       |
# |    explained_variance   | 0.00882     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.32        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000246   |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 5             |
# |    time_elapsed         | 238           |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 3.7527876e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0693        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.15          |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000348     |
# |    value_loss           | 1.28          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 6             |
# |    time_elapsed         | 296           |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 1.6322709e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.000996      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.438         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -4.86e-05     |
# |    value_loss           | 1.24          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 7             |
# |    time_elapsed         | 350           |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 5.4189004e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00296       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.171         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -2.37e-05     |
# |    value_loss           | 0.753         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 8             |
# |    time_elapsed         | 397           |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 2.0344858e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00115       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0652        |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000198     |
# |    value_loss           | 0.352         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 9            |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 5.761394e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0119       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0735       |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 9.1e-05      |
# |    value_loss           | 0.373        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 10           |
# |    time_elapsed         | 495          |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 8.662813e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00084      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.248        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000197    |
# |    value_loss           | 0.767        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 11            |
# |    time_elapsed         | 547           |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 3.2525742e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0235        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 34            |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000279     |
# |    value_loss           | 74.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 12           |
# |    time_elapsed         | 599          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 8.435571e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0425       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.124        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -5e-05       |
# |    value_loss           | 0.48         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 13            |
# |    time_elapsed         | 652           |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 1.4070189e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.001         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0712        |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -7.24e-05     |
# |    value_loss           | 0.38          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 14            |
# |    time_elapsed         | 703           |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.0677031e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0234        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.114         |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00016      |
# |    value_loss           | 0.314         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 15           |
# |    time_elapsed         | 755          |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 9.573996e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.054        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0862       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000202    |
# |    value_loss           | 0.226        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 16            |
# |    time_elapsed         | 807           |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.0253745e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0565        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.189         |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000153     |
# |    value_loss           | 0.399         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 17            |
# |    time_elapsed         | 859           |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 1.5652273e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.0307        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0995        |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000301     |
# |    value_loss           | 0.23          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 18            |
# |    time_elapsed         | 907           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 0.00012217322 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0251        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 167           |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 0.000618      |
# |    value_loss           | 443           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 19            |
# |    time_elapsed         | 955           |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 1.1162134e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0256        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.112         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 3.05e-05      |
# |    value_loss           | 1.22          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 20            |
# |    time_elapsed         | 1003          |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.8156366e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0896        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.106         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000164     |
# |    value_loss           | 0.506         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 21            |
# |    time_elapsed         | 1051          |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 4.6017813e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0695        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0867        |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 0.000151      |
# |    value_loss           | 0.355         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 22           |
# |    time_elapsed         | 1099         |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 1.417473e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.202        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.137        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000216    |
# |    value_loss           | 0.346        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 23           |
# |    time_elapsed         | 1147         |
# |    total_timesteps      | 11776        |
# | train/                  |              |
# |    approx_kl            | 5.129259e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0114       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.081        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | 2.57e-05     |
# |    value_loss           | 0.284        |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 10             |
# |    iterations           | 24             |
# |    time_elapsed         | 1197           |
# |    total_timesteps      | 12288          |
# | train/                  |                |
# |    approx_kl            | 1.44174555e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | -0.00116       |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.0806         |
# |    n_updates            | 230            |
# |    policy_gradient_loss | -0.000221      |
# |    value_loss           | 0.197          |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 25           |
# |    time_elapsed         | 1251         |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 8.640927e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0049       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.112        |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000148    |
# |    value_loss           | 0.29         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 26            |
# |    time_elapsed         | 1308          |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 3.2632845e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00432      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.121         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000528     |
# |    value_loss           | 0.259         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 27            |
# |    time_elapsed         | 1365          |
# |    total_timesteps      | 13824         |
# | train/                  |               |
# |    approx_kl            | 2.5682617e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0114        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.153         |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000493     |
# |    value_loss           | 0.21          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 28           |
# |    time_elapsed         | 1421         |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 3.603869e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.022       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0444       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000613    |
# |    value_loss           | 0.126        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 29            |
# |    time_elapsed         | 1475          |
# |    total_timesteps      | 14848         |
# | train/                  |               |
# |    approx_kl            | 7.1965624e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0197        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.106         |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000105     |
# |    value_loss           | 0.206         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 30            |
# |    time_elapsed         | 1530          |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 1.1627912e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0123       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.242         |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000233     |
# |    value_loss           | 0.511         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 31            |
# |    time_elapsed         | 1588          |
# |    total_timesteps      | 15872         |
# | train/                  |               |
# |    approx_kl            | 1.2669712e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00541      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0697        |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000167     |
# |    value_loss           | 0.136         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 32           |
# |    time_elapsed         | 1645         |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 1.887558e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00308     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0717       |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -9.71e-06    |
# |    value_loss           | 0.12         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 33            |
# |    time_elapsed         | 1699          |
# |    total_timesteps      | 16896         |
# | train/                  |               |
# |    approx_kl            | 3.4865225e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.136         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 7.27          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000215     |
# |    value_loss           | 11            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 34           |
# |    time_elapsed         | 1748         |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0003402416 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0145      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 144          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000816    |
# |    value_loss           | 501          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 35           |
# |    time_elapsed         | 1795         |
# |    total_timesteps      | 17920        |
# | train/                  |              |
# |    approx_kl            | 0.0001319577 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0571       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 48.7         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000201     |
# |    value_loss           | 109          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 36            |
# |    time_elapsed         | 1844          |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 6.9695176e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00216      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.128         |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 5.96e-05      |
# |    value_loss           | 1.51          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 37            |
# |    time_elapsed         | 1892          |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 1.8072082e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0117       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.115         |
# |    n_updates            | 360           |
# |    policy_gradient_loss | 5.9e-05       |
# |    value_loss           | 1.14          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 38            |
# |    time_elapsed         | 1940          |
# |    total_timesteps      | 19456         |
# | train/                  |               |
# |    approx_kl            | 2.2483175e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.114         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.151         |
# |    n_updates            | 370           |
# |    policy_gradient_loss | 0.000159      |
# |    value_loss           | 0.906         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 39           |
# |    time_elapsed         | 1988         |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 2.265384e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0861       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 8.68e-05     |
# |    value_loss           | 0.551        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 40           |
# |    time_elapsed         | 2038         |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 7.786718e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0206      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.066        |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000828    |
# |    value_loss           | 0.376        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 10            |
# |    iterations           | 41            |
# |    time_elapsed         | 2092          |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 1.8442981e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.639         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0755        |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -4.09e-06     |
# |    value_loss           | 0.276         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 42            |
# |    time_elapsed         | 2152          |
# |    total_timesteps      | 21504         |
# | train/                  |               |
# |    approx_kl            | 4.5551336e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00903      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0697        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000366     |
# |    value_loss           | 0.186         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 43            |
# |    time_elapsed         | 2214          |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 1.5538651e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0078        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0552        |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000187     |
# |    value_loss           | 0.148         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 44            |
# |    time_elapsed         | 2273          |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 2.5215908e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00326       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0894        |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00029      |
# |    value_loss           | 0.148         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 45            |
# |    time_elapsed         | 2333          |
# |    total_timesteps      | 23040         |
# | train/                  |               |
# |    approx_kl            | 4.5593013e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0225        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0781        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000345     |
# |    value_loss           | 0.192         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 46            |
# |    time_elapsed         | 2392          |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 1.2708362e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0137       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.108         |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -8.42e-05     |
# |    value_loss           | 0.177         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 47           |
# |    time_elapsed         | 2453         |
# |    total_timesteps      | 24064        |
# | train/                  |              |
# |    approx_kl            | 2.344884e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0142       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.107        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000271    |
# |    value_loss           | 0.177        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 48          |
# |    time_elapsed         | 2514        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 3.52629e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.017      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0581      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.000421   |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 49            |
# |    time_elapsed         | 2576          |
# |    total_timesteps      | 25088         |
# | train/                  |               |
# |    approx_kl            | 2.3652567e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00754       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.132         |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.000349     |
# |    value_loss           | 0.207         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 50            |
# |    time_elapsed         | 2634          |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 0.00077445933 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.1           |
# |    learning_rate        | 1e-06         |
# |    loss                 | 193           |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000327     |
# |    value_loss           | 492           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 51            |
# |    time_elapsed         | 2686          |
# |    total_timesteps      | 26112         |
# | train/                  |               |
# |    approx_kl            | 4.0183077e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00339      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.213         |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 0.00018       |
# |    value_loss           | 1.46          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 52            |
# |    time_elapsed         | 2738          |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00011517049 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0408        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 26            |
# |    n_updates            | 510           |
# |    policy_gradient_loss | 0.000111      |
# |    value_loss           | 76.9          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 53            |
# |    time_elapsed         | 2789          |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 3.3952412e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00637      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.201         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | 0.000647      |
# |    value_loss           | 1.09          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 54            |
# |    time_elapsed         | 2841          |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 9.0846675e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.042        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.147         |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000688     |
# |    value_loss           | 0.777         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 55            |
# |    time_elapsed         | 2892          |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 4.2887405e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0737        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.158         |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -7.4e-05      |
# |    value_loss           | 0.598         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 56            |
# |    time_elapsed         | 2942          |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 2.0671287e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.114         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.125         |
# |    n_updates            | 550           |
# |    policy_gradient_loss | 6.08e-05      |
# |    value_loss           | 0.472         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 57            |
# |    time_elapsed         | 2994          |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 1.1924654e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0905        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.161         |
# |    n_updates            | 560           |
# |    policy_gradient_loss | 0.000114      |
# |    value_loss           | 0.433         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 58            |
# |    time_elapsed         | 3047          |
# |    total_timesteps      | 29696         |
# | train/                  |               |
# |    approx_kl            | 1.0499032e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.0195       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.119         |
# |    n_updates            | 570           |
# |    policy_gradient_loss | -4.62e-05     |
# |    value_loss           | 0.338         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 59           |
# |    time_elapsed         | 3100         |
# |    total_timesteps      | 30208        |
# | train/                  |              |
# |    approx_kl            | 3.205682e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.0596       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.177        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000159    |
# |    value_loss           | 0.328        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 60            |
# |    time_elapsed         | 3153          |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 1.2245611e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0135        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.149         |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -8.82e-05     |
# |    value_loss           | 0.252         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 61            |
# |    time_elapsed         | 3206          |
# |    total_timesteps      | 31232         |
# | train/                  |               |
# |    approx_kl            | 1.2948527e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.185         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0919        |
# |    n_updates            | 600           |
# |    policy_gradient_loss | -7.39e-05     |
# |    value_loss           | 0.207         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 62            |
# |    time_elapsed         | 3259          |
# |    total_timesteps      | 31744         |
# | train/                  |               |
# |    approx_kl            | 2.1591433e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.147         |
# |    learning_rate        | 1e-06         |
# ...
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.167         |
# |    n_updates            | 1780          |
# |    policy_gradient_loss | -0.000443     |
# |    value_loss           | 0.312         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 180          |
# |    time_elapsed         | 9375         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 1.565786e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.00651      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.155        |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | 0.000111     |
# |    value_loss           | 0.296        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 181           |
# |    time_elapsed         | 9428          |
# |    total_timesteps      | 92672         |
# | train/                  |               |
# |    approx_kl            | 4.7913054e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.85         |
# |    explained_variance   | -0.0105       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.15          |
# |    n_updates            | 1800          |
# |    policy_gradient_loss | -0.00036      |
# |    value_loss           | 0.267         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 182          |
# |    time_elapsed         | 9480         |
# |    total_timesteps      | 93184        |
# | train/                  |              |
# |    approx_kl            | 7.542921e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.259        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 11.9         |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | 0.000173     |
# |    value_loss           | 28.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 183          |
# |    time_elapsed         | 9533         |
# |    total_timesteps      | 93696        |
# | train/                  |              |
# |    approx_kl            | 2.790452e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 13.2         |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.000243    |
# |    value_loss           | 23.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 184          |
# |    time_elapsed         | 9586         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 8.039537e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | -0.0591      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0567       |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -4.89e-05    |
# |    value_loss           | 0.321        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 185          |
# |    time_elapsed         | 9638         |
# |    total_timesteps      | 94720        |
# | train/                  |              |
# |    approx_kl            | 9.016029e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.84        |
# |    explained_variance   | 0.0163       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0438       |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.000316    |
# |    value_loss           | 0.221        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 186           |
# |    time_elapsed         | 9691          |
# |    total_timesteps      | 95232         |
# | train/                  |               |
# |    approx_kl            | 5.3647556e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.84         |
# |    explained_variance   | 0.277         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0736        |
# |    n_updates            | 1850          |
# |    policy_gradient_loss | -3.77e-05     |
# |    value_loss           | 0.231         |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 9              |
# |    iterations           | 187            |
# |    time_elapsed         | 9744           |
# |    total_timesteps      | 95744          |
# | train/                  |                |
# |    approx_kl            | 0.000101821264 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.84          |
# |    explained_variance   | -0.0348        |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.0689         |
# |    n_updates            | 1860           |
# |    policy_gradient_loss | -0.000426      |
# |    value_loss           | 0.188          |
# --------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 188         |
# |    time_elapsed         | 9797        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.000160572 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.84       |
# |    explained_variance   | -0.046      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0483      |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.000563   |
# |    value_loss           | 0.148       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 189          |
# |    time_elapsed         | 9849         |
# |    total_timesteps      | 96768        |
# | train/                  |              |
# |    approx_kl            | 0.0023889067 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.29         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 172          |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 439          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 190           |
# |    time_elapsed         | 9901          |
# |    total_timesteps      | 97280         |
# | train/                  |               |
# |    approx_kl            | 4.8911897e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.81         |
# |    explained_variance   | 0.557         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 6.95          |
# |    n_updates            | 1890          |
# |    policy_gradient_loss | 6.6e-05       |
# |    value_loss           | 30.7          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 191           |
# |    time_elapsed         | 9954          |
# |    total_timesteps      | 97792         |
# | train/                  |               |
# |    approx_kl            | 0.00014836306 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.81         |
# |    explained_variance   | 0.391         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 41.3          |
# |    n_updates            | 1900          |
# |    policy_gradient_loss | -0.000703     |
# |    value_loss           | 69            |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 192          |
# |    time_elapsed         | 10006        |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 8.040434e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.81        |
# |    explained_variance   | -0.0111      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.109        |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | 0.001        |
# |    value_loss           | 1.31         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 193           |
# |    time_elapsed         | 10059         |
# |    total_timesteps      | 98816         |
# | train/                  |               |
# |    approx_kl            | 0.00019404804 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.82         |
# |    explained_variance   | 0.00584       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0902        |
# |    n_updates            | 1920          |
# |    policy_gradient_loss | -0.000246     |
# |    value_loss           | 0.671         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 194           |
# |    time_elapsed         | 10111         |
# |    total_timesteps      | 99328         |
# | train/                  |               |
# |    approx_kl            | 0.00015320361 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.82         |
# |    explained_variance   | -0.0623       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0446        |
# |    n_updates            | 1930          |
# |    policy_gradient_loss | -7.85e-05     |
# |    value_loss           | 0.537         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 195           |
# |    time_elapsed         | 10164         |
# |    total_timesteps      | 99840         |
# | train/                  |               |
# |    approx_kl            | 0.00015444914 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.83         |
# |    explained_variance   | 0.00181       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0758        |
# |    n_updates            | 1940          |
# |    policy_gradient_loss | -0.000705     |
# |    value_loss           | 0.44          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 9             |
# |    iterations           | 196           |
# |    time_elapsed         | 10221         |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00012523332 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.83         |
# |    explained_variance   | -0.0453       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0479        |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | -4.42e-05     |
# |    value_loss           | 0.272         |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4796\1095529980.py in <module>
#       1 #start of training ai model
# ----> 2 model.learn(total_timesteps=1000000, callback=callback)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     315     ) -> PPOSelf:
#     316
# --> 317         return super().learn(
#     318             total_timesteps=total_timesteps,
#     319             callback=callback,
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps, progress_bar)
#     281                 self.logger.dump(step=self.num_timesteps)
#     282
# --> 283             self.train()
#     284
#     285         callback.on_training_end()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py in train(self)
#     274                 # Optimization step
#     275                 self.policy.optimizer.zero_grad()
# --> 276                 loss.backward()
#     277                 # Clip grad norm
#     278                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     486                 inputs=inputs,
#     487             )
# --> 488         torch.autograd.backward(
#     489             self, gradient, retain_graph, create_graph, inputs=inputs
#     490         )
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     # some Python versions print out the first line of a multi-line function
#     196     # calls in the traceback and some print out the last line
# --> 197     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
model = PPO.load('./train/best_model_100000')

# %%
state = env.reset()

# %%
state = env.reset()

while True: 
    
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# C:\Users\Devon\anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6496\3414477160.py in <module>
#       3 while True:
#       4
# ----> 5     action, _ = model.predict(state)
#       6     state, reward, done, info = env.step(action)
#       7     env.render()
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\base_class.py in predict(self, observation, state, episode_start, deterministic)
#     630             (used in recurrent policies)
#     631         """
# --> 632         return self.policy.predict(observation, state, episode_start, deterministic)
#     633
#     634     def set_random_seed(self, seed: Optional[int] = None) -> None:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in predict(self, observation, state, episode_start, deterministic)
#     334
#     335         with th.no_grad():
# --> 336             actions = self._predict(observation, deterministic=deterministic)
#     337         # Convert to numpy, and reshape to the original action shape
#     338         actions = actions.cpu().numpy().reshape((-1,) + self.action_space.shape)
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in _predict(self, observation, deterministic)
#     627         :return: Taken action according to the policy
#     628         """
# --> 629         return self.get_distribution(observation).get_actions(deterministic=deterministic)
#     630
#     631     def evaluate_actions(self, obs: th.Tensor, actions: th.Tensor) -> Tuple[th.Tensor, th.Tensor, th.Tensor]:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in get_distribution(self, obs)
#     656         features = self.extract_features(obs)
#     657         latent_pi = self.mlp_extractor.forward_actor(features)
# --> 658         return self._get_action_dist_from_latent(latent_pi)
#     659
#     660     def predict_values(self, obs: th.Tensor) -> th.Tensor:
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\policies.py in _get_action_dist_from_latent(self, latent_pi)
#     607         elif isinstance(self.action_dist, CategoricalDistribution):
#     608             # Here mean_actions are the logits before the softmax
# --> 609             return self.action_dist.proba_distribution(action_logits=mean_actions)
#     610         elif isinstance(self.action_dist, MultiCategoricalDistribution):
#     611             # Here mean_actions are the flattened logits
#
# ~\anaconda3\lib\site-packages\stable_baselines3\common\distributions.py in proba_distribution(self, action_logits)
#     273
#     274     def proba_distribution(self, action_logits: th.Tensor) -> "CategoricalDistribution":
# --> 275         self.distribution = Categorical(logits=action_logits)
#     276         return self
#     277
#
# ~\anaconda3\lib\site-packages\torch\distributions\categorical.py in __init__(self, probs, logits, validate_args)
#      60                 raise ValueError("`logits` parameter must be at least one-dimensional.")
#      61             # Normalize
# ---> 62             self.logits = logits - logits.logsumexp(dim=-1, keepdim=True)
#      63         self._param = self.probs if probs is not None else self.logits
#      64         self._num_events = self._param.size()[-1]
#
# KeyboardInterrupt:

# %%
env.close()
